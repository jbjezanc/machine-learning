# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
df.shape
# Out:
# (9704, 11)

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline    4898
# Diesel      4806
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
condition = df['origin'] == 'Asia'
df.loc[condition, 'fuel_efficiency_mpg'].max()
# Out:
# np.float64(23.759122836520497)

# %%
hp_med = df['horsepower'].median()
hp_mode = df['horsepower'].mode().iloc[0]

# %%
hp_med
# Out:
# np.float64(149.0)

# %%
hp_mode
# Out:
# np.float64(152.0)

# %%
df['horsepower'] = df['horsepower'].fillna(hp_mode)

# %%
hp_med = df['horsepower'].median()
hp_med
# Out:
# np.float64(152.0)

# %%
df.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower               0
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
X = df.loc[condition][['vehicle_weight', 'model_year']].head(7)
X
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %%
XTX = X.to_numpy().T @ X.to_numpy()

# %%
XTX
# Out:
# array([[62248334.33150762, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100, 1200])

# %%
w = np.linalg.inv(XTX) @ X.to_numpy().T @ y
w.sum()
# Out:
# np.float64(0.5187709081074016)
